# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/cleaned_data.csv')
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   period_end_date       compset_group business_entity_doing_business_as_name  \
# 0          0 days      Apparel Retail                                  Oysho
# 1          0 days  Fitness & Exercise                              ClassPass
# 2          0 days       Food Products                          Almond Breeze
# 3          0 days         Restaurants                                  Sonic
# 4          0 days      Apparel Retail                       Urban Outfitters
#
#   legal_entity_name ultimate_parent_legal_entity_name  followers  pictures  \
# 0        Inditex SA         Pontegadea Inversiones SL        0.0      82.0
# 1  Classpass UK Ltd                  Classpass UK Ltd        0.0      32.0
# 2       HP Hood LLC                       HP Hood LLC        0.0      39.0
# 3             Sonic                Inspire Brands Inc        0.0       6.0
# 4  Urban Outfitters                  Urban Outfitters  3045130.0     508.0
#
#    videos  comments      likes  Posts  Avg_Likes_Per_Post  Interaction  \
# 0     1.0    1699.0   290664.0   83.0         3501.975904     290747.0
# 1     0.0     738.0     5641.0   32.0          176.281250       5673.0
# 2     0.0     235.0     5097.0   39.0          130.692308       5136.0
# 3     1.0      93.0     1595.0    7.0          227.857143       1602.0
# 4     1.0   49121.0  8203979.0  509.0        16117.836935    8204488.0
#
#    Avg_Comments_Per_Post  Avg_Interaction_Per_Post   Avg_Likes_Per_Comment    \
# 0              20.469880                3502.975904               171.079459
# 1              23.062500                 177.281250                 7.643631
# 2               6.025641                 131.692308                21.689362
# 3              13.285714                 228.857143                17.150538
# 4              96.504912               16118.836935               167.015716
#
#    Avg_Likes_Per_Follower    Avg_Comments_Per_Follower    \
# 0                  0.000000                     0.000000
# 1                  0.000000                     0.000000
# 2                  0.000000                     0.000000
# 3                  0.000000                     0.000000
# 4                  2.694131                     0.016131
#
#    Avg_Interaction_Per_Follower
# 0                        0.000000
# 1                        0.000000
# 2                        0.000000
# 3                        0.000000
# 4                        2.694298

# %%
#scatter plot of posts vs. likes and likes vs. comments as subplots

#posts vs. likes
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
ax[0].scatter(df['Posts'], df['likes'], color='blue')
ax[0].set_title('Posts vs. Likes')
ax[0].set_xlabel('Posts')
ax[0].set_ylabel('Likes')

#likes vs. comments
ax[1].scatter(df['likes'], df['comments'], color='red')
ax[1].set_title('Likes vs. Comments')
ax[1].set_xlabel('Likes')
ax[1].set_ylabel('Comments')

plt.tight_layout()
plt.show()

# %%
#scatter plot of Posts vs. followers
plt.figure(figsize=(8, 6))
plt.scatter(df['Posts'], df['followers'], color='green')
plt.title('Posts vs. Followers')
plt.xlabel('Posts')
plt.ylabel('Followers')
plt.show()

# %%
df[df["pictures"] == df["pictures"].max()].index[0]
# Out:
# 214061

# %%
df.iloc[214061]
# Out:
# period_end_date                                    2156 days
# compset_group                             Study (All Brands)
# business_entity_doing_business_as_name            All Brands
# legal_entity_name                                        NaN
# ultimate_parent_legal_entity_name                        NaN
# followers                                       2760049428.0
# pictures                                            141746.0
# videos                                               22342.0
# comments                                          14073115.0
# likes                                            460119978.0
# Posts                                               164088.0
# Avg_Likes_Per_Post                                2804.10498
# Interaction                                      460284066.0
# Avg_Comments_Per_Post                              85.765656
# Avg_Interaction_Per_Post                          2805.10498
# Avg_Likes_Per_Comment                              32.694963
# Avg_Likes_Per_Follower                              0.166707
# Avg_Comments_Per_Follower                           0.005099
# Avg_Interaction_Per_Follower                        0.166767
# Name: 214061, dtype: object
